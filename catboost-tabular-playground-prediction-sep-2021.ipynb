# %% [markdown]
# <a href="https://www.kaggle.com/code/lonnieqin/catboost-tabular-playground-prediction-sep-2021?scriptVersionId=115162491" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # CatBoost Tabular Playground Prediction(Sep 2021)
# ## Table of Contents
# - Import Packages
# - Import Datasets
# - EDA & Preprocessing
# - Model Development & Evaluation
# - Submission

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, log_loss, roc_auc_score

# %% [markdown]
# ## Import datasets

# %%
train = pd.read_csv("/kaggle/input/tabular-playground-series-sep-2021/train.csv")
test = pd.read_csv("/kaggle/input/tabular-playground-series-sep-2021/test.csv")

# %%
train.head()
# Out:
#    id       f1        f2         f3        f4       f5        f6       f7  \
# 0   0  0.10859  0.004314    -37.566  0.017364  0.28915 -10.25100   135.12
# 1   1  0.10090  0.299610  11822.000  0.276500  0.45970  -0.83733  1721.90
# 2   2  0.17803 -0.006980    907.270  0.272140  0.45948   0.17327  2298.00
# 3   3  0.15236  0.007259    780.100  0.025179  0.51947   7.49140   112.51
# 4   4  0.11623  0.502900   -109.150  0.297910  0.34490  -0.40932  2538.90
#
#          f8            f9  ...     f110    f111     f112      f113      f114  \
# 0  168900.0  3.992400e+14  ... -12.2280  1.7482  1.90960  -7.11570   4378.80
# 1  119810.0  3.874100e+15  ... -56.7580  4.1684  0.34808   4.14200    913.23
# 2  360650.0  1.224500e+13  ...  -5.7688  1.2042  0.26290   8.13120  45119.00
# 3  259490.0  7.781400e+13  ... -34.8580  2.0694  0.79631 -16.33600   4952.40
# 4   65332.0  1.907200e+15  ... -13.6410  1.5298  1.14640  -0.43124   3856.50
#
#      f115          f116    f117     f118  claim
# 0  1.2096  8.613400e+14   140.1  1.01770      1
# 1  1.2464  7.575100e+15  1861.0  0.28359      0
# 2  1.1764  3.218100e+14  3838.2  0.40690      1
# 3  1.1784  4.533000e+12  4889.1  0.51486      1
# 4  1.4830 -8.991300e+12     NaN  0.23049      1
#
# [5 rows x 120 columns]

# %%
test.head()
# Out:
#        id        f1        f2        f3       f4       f5       f6       f7  \
# 0  957919  0.165850  0.487050   1295.00  0.02310  0.31900  0.90188   573.29
# 1  957920  0.129650  0.373480   1763.00  0.72884  0.33247 -1.26310   875.55
# 2  957921  0.120190  0.445210    736.26  0.04615  0.29605  0.31665  2659.50
# 3  957922  0.054008  0.395960    996.14  0.85934  0.36678 -0.17060   386.56
# 4  957923  0.079947 -0.006919  10574.00  0.34845  0.45008 -1.84200  3027.00
#
#          f8            f9  ...     f109     f110    f111      f112     f113  \
# 0    3743.7  2.705700e+12  ...  0.16253 -22.1890  2.0655  0.430880 -10.7410
# 1  554370.0  5.955700e+14  ...  0.81528  -1.6342  1.5736 -1.071200  11.8320
# 2  317140.0  3.977800e+14  ...  0.81831 -32.7800  2.1364 -1.931200  -3.2804
# 3  325680.0 -3.432200e+13  ...  0.86559  -2.4162  1.5199 -0.011633   1.3840
# 4  428150.0  9.291500e+11  ...  0.25190 -18.6300  3.7387  0.757080  -4.9405
#
#       f114    f115          f116    f117     f118
# 0  81606.0  1.1940  1.980400e+14  2017.1  0.46357
# 1  90114.0  1.1507  4.388000e+16  6638.9  0.28125
# 2  37739.0  1.1548  1.718100e+14  5844.0  0.13797
# 3  26849.0  1.1490  2.138800e+17  6173.3  0.32910
# 4  50336.0  1.2488  2.151300e+17  2250.1  0.33796
#
# [5 rows x 119 columns]

# %% [markdown]
# ## EDA & Data Preprocessing

# %% [markdown]
# ### Drop ID columns

# %%
train.pop("id")
test_ids = test.pop("id")

# %% [markdown]
# ### Get Train data Targets

# %%
train_targets = train.pop("claim")

# %%
train_targets.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: claim, dtype: int64

# %% [markdown]
# The labels looks balanced.

# %%
sns.countplot(train_targets)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='claim', ylabel='count'>

# %% [markdown]
# Let's see statistic info between train set and test set and compare their differences, which are very small execpt for their total numbers.  Some of the parameters has a great difference, so I will apply log transformation to reduce their skewness.

# %%
train_desc = train.describe()
train_desc.transpose()
# Out:
#          count          mean           std           min           25%  \
# f1    942672.0  9.020086e-02  4.356374e-02 -1.499100e-01  7.022700e-02
# f2    942729.0  3.459637e-01  1.462507e-01 -1.904400e-02  2.830500e-01
# f3    942428.0  4.068744e+03  6.415829e+03 -9.421700e+03  4.184300e+02
# f4    942359.0  2.012140e-01  2.125103e-01 -8.212200e-02  3.508650e-02
# f5    942514.0  3.048693e-01  1.453425e-01 -6.989800e-03  2.405200e-01
# ...        ...           ...           ...           ...           ...
# f114  942481.0  6.315297e+04  9.243502e+04 -8.197700e+04  2.443200e+03
# f115  942360.0  1.208876e+00  1.149588e-01  9.052700e-01  1.146800e+00
# f116  942330.0  4.276905e+16  6.732441e+16 -8.944400e+15  2.321100e+14
# f117  942512.0  3.959205e+03  3.155992e+03 -4.152400e+02  1.306200e+03
# f118  942707.0  5.592672e-01  4.084261e-01 -1.512400e-01  2.765600e-01
#
#                50%           75%           max
# f1    9.013500e-02  1.165000e-01  4.151700e-01
# f2    3.891000e-01  4.584500e-01  5.189900e-01
# f3    1.279500e+03  4.444400e+03  3.954400e+04
# f4    1.370000e-01  2.971000e-01  1.319900e+00
# f5    3.277900e-01  4.128300e-01  5.547500e-01
# ...            ...           ...           ...
# f114  1.947900e+04  8.848800e+04  5.260500e+05
# f115  1.177200e+00  1.242000e+00  1.886700e+00
# f116  1.327500e+16  5.278700e+16  3.249900e+17
# f117  3.228000e+03  6.137900e+03  1.315100e+04
# f118  4.734400e-01  7.462100e-01  2.743600e+00
#
# [118 rows x 8 columns]

# %%
test_desc = test.describe()
test_desc.transpose()
# Out:
#          count          mean           std           min           25%  \
# f1    485662.0  9.019114e-02  4.353777e-02 -1.531900e-01  7.021100e-02
# f2    485583.0  3.461425e-01  1.458888e-01 -1.906000e-02  2.836600e-01
# f3    485679.0  4.047202e+03  6.383225e+03 -9.436300e+03  4.188350e+02
# f4    485741.0  2.015029e-01  2.125533e-01 -8.071600e-02  3.516900e-02
# f5    485597.0  3.048788e-01  1.454351e-01 -7.006900e-03  2.406000e-01
# ...        ...           ...           ...           ...           ...
# f114  485532.0  6.305129e+04  9.227903e+04 -8.138100e+04  2.474875e+03
# f115  485497.0  1.209049e+00  1.150736e-01  9.007000e-01  1.146800e+00
# f116  485391.0  4.284258e+16  6.743966e+16 -7.749400e+15  2.317850e+14
# f117  485711.0  3.968586e+03  3.161273e+03 -4.162400e+02  1.310000e+03
# f118  485589.0  5.587338e-01  4.084724e-01 -1.869600e-01  2.767600e-01
#
#                50%           75%           max
# f1    9.017300e-02  1.165075e-01  4.129000e-01
# f2    3.889400e-01  4.583100e-01  5.198800e-01
# f3    1.277900e+03  4.421400e+03  3.984100e+04
# f4    1.373500e-01  2.971600e-01  1.310200e+00
# f5    3.280200e-01  4.128100e-01  5.555800e-01
# ...            ...           ...           ...
# f114  1.942900e+04  8.830950e+04  5.215400e+05
# f115  1.177200e+00  1.242300e+00  1.877900e+00
# f116  1.330400e+16  5.284700e+16  3.239500e+17
# f117  3.237100e+03  6.157300e+03  1.319800e+04
# f118  4.737900e-01  7.449700e-01  2.732000e+00
#
# [118 rows x 8 columns]

# %%
desc_delta = train_desc - test_desc
desc_delta.transpose()
# Out:
#          count          mean           std           min           25%  \
# f1    457010.0  9.723625e-06  2.597197e-05  3.280000e-03  1.600000e-05
# f2    457146.0 -1.788055e-04  3.619441e-04  1.600000e-05 -6.100000e-04
# f3    456749.0  2.154181e+01  3.260448e+01  1.460000e+01 -4.050000e-01
# f4    456618.0 -2.889054e-04 -4.290765e-05 -1.406000e-03 -8.250000e-05
# f5    456917.0 -9.531270e-06 -9.253989e-05  1.710000e-05 -8.000000e-05
# ...        ...           ...           ...           ...           ...
# f114  456949.0  1.016860e+02  1.559844e+02 -5.960000e+02 -3.167500e+01
# f115  456863.0 -1.730104e-04 -1.147484e-04  4.570000e-03  0.000000e+00
# f116  456939.0 -7.352366e+13 -1.152458e+14 -1.195000e+15  3.250000e+11
# f117  456801.0 -9.380843e+00 -5.281491e+00  1.000000e+00 -3.800000e+00
# f118  457118.0  5.333853e-04 -4.631938e-05  3.572000e-02 -2.000000e-04
#
#                50%           75%           max
# f1   -3.800000e-05 -7.500000e-06  2.270000e-03
# f2    1.600000e-04  1.400000e-04 -8.900000e-04
# f3    1.600000e+00  2.300000e+01 -2.970000e+02
# f4   -3.500000e-04 -6.000000e-05  9.700000e-03
# f5   -2.300000e-04  2.000000e-05 -8.300000e-04
# ...            ...           ...           ...
# f114  5.000000e+01  1.785000e+02  4.510000e+03
# f115  0.000000e+00 -3.000000e-04  8.800000e-03
# f116 -2.900000e+13 -6.000000e+13  1.040000e+15
# f117 -9.100000e+00 -1.940000e+01 -4.700000e+01
# f118 -3.500000e-04  1.240000e-03  1.160000e-02
#
# [118 rows x 8 columns]

# %% [markdown]
# ### Add extra features

# %%
for data in [train, test]:
    data['n_nans'] = data.isnull().sum(axis=1)
    data['std'] = data.std(axis=1)
    data['var'] = data.var(axis=1)

# %%
train.head()
# Out:
#         f1        f2         f3        f4       f5        f6       f7  \
# 0  0.10859  0.004314    -37.566  0.017364  0.28915 -10.25100   135.12
# 1  0.10090  0.299610  11822.000  0.276500  0.45970  -0.83733  1721.90
# 2  0.17803 -0.006980    907.270  0.272140  0.45948   0.17327  2298.00
# 3  0.15236  0.007259    780.100  0.025179  0.51947   7.49140   112.51
# 4  0.11623  0.502900   -109.150  0.297910  0.34490  -0.40932  2538.90
#
#          f8            f9        f10  ...     f112      f113      f114  \
# 0  168900.0  3.992400e+14     86.489  ...  1.90960  -7.11570   4378.80
# 1  119810.0  3.874100e+15   9953.600  ...  0.34808   4.14200    913.23
# 2  360650.0  1.224500e+13  15827.000  ...  0.26290   8.13120  45119.00
# 3  259490.0  7.781400e+13    -36.837  ...  0.79631 -16.33600   4952.40
# 4   65332.0  1.907200e+15    144.120  ...  1.14640  -0.43124   3856.50
#
#      f115          f116    f117     f118  n_nans           std           var
# 0  1.2096  8.613400e+14   140.1  1.01770       1  1.008624e+15  1.015491e+30
# 1  1.2464  7.575100e+15  1861.0  0.28359       0  2.933337e+15  8.586285e+30
# 2  1.1764  3.218100e+14  3838.2  0.40690       5  3.092107e+13  9.544504e+26
# 3  1.1784  4.533000e+12  4889.1  0.51486       2  1.755542e+14  3.077004e+28
# 4  1.4830 -8.991300e+12     NaN  0.23049       8  9.771993e+14  9.529719e+29
#
# [5 rows x 121 columns]

# %%
test.head()
# Out:
#          f1        f2        f3       f4       f5       f6       f7        f8  \
# 0  0.165850  0.487050   1295.00  0.02310  0.31900  0.90188   573.29    3743.7
# 1  0.129650  0.373480   1763.00  0.72884  0.33247 -1.26310   875.55  554370.0
# 2  0.120190  0.445210    736.26  0.04615  0.29605  0.31665  2659.50  317140.0
# 3  0.054008  0.395960    996.14  0.85934  0.36678 -0.17060   386.56  325680.0
# 4  0.079947 -0.006919  10574.00  0.34845  0.45008 -1.84200  3027.00  428150.0
#
#              f9       f10  ...      f112     f113     f114    f115  \
# 0  2.705700e+12  6221.000  ...  0.430880 -10.7410  81606.0  1.1940
# 1  5.955700e+14   934.430  ... -1.071200  11.8320  90114.0  1.1507
# 2  3.977800e+14   131.810  ... -1.931200  -3.2804  37739.0  1.1548
# 3 -3.432200e+13   -26.473  ... -0.011633   1.3840  26849.0  1.1490
# 4  9.291500e+11  5999.400  ...  0.757080  -4.9405  50336.0  1.2488
#
#            f116    f117     f118  n_nans           std           var
# 0  1.980400e+14  2017.1  0.46357       1  5.565679e+15  3.092849e+31
# 1  4.388000e+16  6638.9  0.28125       0  4.063838e+15  1.648596e+31
# 2  1.718100e+14  5844.0  0.13797       1  4.037287e+13  1.626325e+27
# 3  2.138800e+17  6173.3  0.32910       0  1.991461e+16  3.958835e+32
# 4  2.151300e+17  2250.1  0.33796       0  1.972051e+16  3.883027e+32
#
# [5 rows x 121 columns]

# %% [markdown]
# ## Feature Scaling

# %%
columns = list(train.columns)
for item in train.columns:
    if abs(train[item].max()) / (abs(train[item].min()) + 10e-10) > 20:
        train[item] = np.sign(train[item]) * np.log2(np.abs(train[item]) + 1)
        test[item] = np.sign(test[item]) * np.log2(np.abs(test[item]) + 1)
    train_mean = train[item].mean()
    train_std = train[item].std()
    train[item] = (train[item] - train_mean) / train_std
    test[item] = (test[item] - train_mean) / train_std
    # Missing Value Imputation seems to have a bad effect to final results
    #train[item].replace(np.NAN, train[item].mean(), inplace=True)
    #test[item].replace(np.NAN, test[item].mean(), inplace=True)

# %% [markdown]
# ## Model Development & Evaluation

# %% [markdown]
# ### Evaluation Method

# %%
def evaluate(valid_targets, probs, name):
    y_pred = np.array(probs > 0.5, dtype=int)
    acc = accuracy_score(valid_targets, y_pred)
    loss = log_loss(valid_targets, y_pred)
    auc = roc_auc_score(valid_targets, probs)
    print("Accuracy score: %.2f"%(acc))
    print("Log loss: %.2f"%(loss))
    print("AUC score:", auc)
    print("Classification report:")
    print(classification_report(valid_targets, y_pred))
    return {
        "name": name, 
        "accuracy_score": acc, 
        "log_loss": loss, 
        "auc": auc
    }

# %% [markdown]
# ## Using CatBoost

# %%
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=10, shuffle=True)
cats = []
index = 1
for train_indices, valid_indices in kfold.split(train, train_targets):
    print("Training with Fold %d"%(index))
    train_features = train.iloc[train_indices]
    train_labels = train_targets.iloc[train_indices]
    valid_features = train.iloc[valid_indices]
    valid_labels = train_targets.iloc[valid_indices]
    cat_params = {
        'iterations': 15000, 
        'loss_function': 'Logloss', 
        'depth': 8, 
        'task_type' : 'GPU',
        'use_best_model': True,
        'eval_metric': 'AUC',
        'early_stopping_rounds': 1000,
        'learning_rate': 0.03,
        'border_count': 32,
        'l2_leaf_reg': 3,
        "verbose": 1000
    }
    cat = CatBoostClassifier(
        **cat_params
    )
    cat.fit(train_features, train_labels, eval_set=[(valid_features, valid_labels)])
    cats.append(cat)
    probs = cat.predict_proba(valid_features)[:, 1]
    result_cat = evaluate(valid_labels, probs, "catboost")
    print(result_cat)
    index += 1
# Out:
# Training with Fold 1
# 0:	learn: 0.7997962	test: 0.8001434	best: 0.8001434 (0)	total: 35ms	remaining: 8m 44s
# 1000:	learn: 0.8372232	test: 0.8116748	best: 0.8116781 (996)	total: 27.9s	remaining: 6m 30s
# 2000:	learn: 0.8562262	test: 0.8122798	best: 0.8123372 (1854)	total: 56.3s	remaining: 6m 6s
# bestTest = 0.8123371601
# bestIteration = 1854
# Shrink model to first 1855 iterations.
# Accuracy score: 0.77
# Log loss: 7.84
# AUC score: 0.8123371634655825
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.65      0.74     48040
#            1       0.72      0.89      0.80     47752
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7729977451144145, 'log_loss': 7.840518786744648, 'auc': 0.8123371634655825}
# Training with Fold 2
# 0:	learn: 0.7996975	test: 0.8012381	best: 0.8012381 (0)	total: 27.4ms	remaining: 6m 50s
# 1000:	learn: 0.8369393	test: 0.8144198	best: 0.8144198 (1000)	total: 28.2s	remaining: 6m 34s
# 2000:	learn: 0.8558285	test: 0.8150154	best: 0.8150156 (1999)	total: 56.2s	remaining: 6m 5s
# 3000:	learn: 0.8717002	test: 0.8151503	best: 0.8151503 (3000)	total: 1m 24s	remaining: 5m 36s
# 4000:	learn: 0.8851911	test: 0.8152879	best: 0.8153799 (3663)	total: 1m 52s	remaining: 5m 8s
# 5000:	learn: 0.8966460	test: 0.8152255	best: 0.8154048 (4517)	total: 2m 19s	remaining: 4m 39s
# bestTest = 0.8154048026
# bestIteration = 4517
# Shrink model to first 4518 iterations.
# Accuracy score: 0.77
# Log loss: 7.79
# AUC score: 0.8154047848033601
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75     48040
#            1       0.72      0.89      0.80     47752
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7744488057457826, 'log_loss': 7.790398223561292, 'auc': 0.8154047848033601}
# Training with Fold 3
# 0:	learn: 0.8002301	test: 0.7942931	best: 0.7942931 (0)	total: 27.5ms	remaining: 6m 53s
# 1000:	learn: 0.8378089	test: 0.8093920	best: 0.8094028 (999)	total: 27.7s	remaining: 6m 26s
# 2000:	learn: 0.8565424	test: 0.8097953	best: 0.8098471 (1835)	total: 55.9s	remaining: 6m 3s
# 3000:	learn: 0.8724515	test: 0.8101081	best: 0.8101412 (2972)	total: 1m 24s	remaining: 5m 36s
# bestTest = 0.8101412058
# bestIteration = 2972
# Shrink model to first 2973 iterations.
# Accuracy score: 0.77
# Log loss: 7.93
# AUC score: 0.8101411954409468
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74     48040
#            1       0.72      0.89      0.79     47752
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7704505595456823, 'log_loss': 7.928495042178155, 'auc': 0.8101411954409468}
# Training with Fold 4
# 0:	learn: 0.7996936	test: 0.8002933	best: 0.8002933 (0)	total: 26.8ms	remaining: 6m 41s
# 1000:	learn: 0.8372602	test: 0.8135071	best: 0.8135188 (994)	total: 27.5s	remaining: 6m 25s
# 2000:	learn: 0.8560330	test: 0.8140833	best: 0.8141668 (1804)	total: 55.1s	remaining: 5m 57s
# 3000:	learn: 0.8720580	test: 0.8143930	best: 0.8144630 (2874)	total: 1m 23s	remaining: 5m 32s
# 4000:	learn: 0.8855769	test: 0.8144816	best: 0.8145262 (3849)	total: 1m 51s	remaining: 5m 6s
# 5000:	learn: 0.8969762	test: 0.8144709	best: 0.8146889 (4333)	total: 2m 19s	remaining: 4m 38s
# bestTest = 0.814688921
# bestIteration = 4333
# Shrink model to first 4334 iterations.
# Accuracy score: 0.77
# Log loss: 7.83
# AUC score: 0.8146888599353668
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.75     48040
#            1       0.72      0.89      0.80     47752
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.773321362953065, 'log_loss': 7.8293387431186945, 'auc': 0.8146888599353668}
# Training with Fold 5
# 0:	learn: 0.8002793	test: 0.7984400	best: 0.7984400 (0)	total: 27.6ms	remaining: 6m 54s
# 1000:	learn: 0.8373231	test: 0.8130289	best: 0.8130370 (999)	total: 27.8s	remaining: 6m 28s
# 2000:	learn: 0.8563191	test: 0.8133871	best: 0.8134896 (1792)	total: 55.6s	remaining: 6m 1s
# bestTest = 0.8134895861
# bestIteration = 1792
# Shrink model to first 1793 iterations.
# Accuracy score: 0.77
# Log loss: 7.83
# AUC score: 0.8134895379178769
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.65      0.74     48040
#            1       0.72      0.89      0.80     47752
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7732900450977117, 'log_loss': 7.830423436870332, 'auc': 0.8134895379178769}
# Training with Fold 6
# 0:	learn: 0.8004904	test: 0.7989657	best: 0.7989657 (0)	total: 27.9ms	remaining: 6m 57s
# 1000:	learn: 0.8374110	test: 0.8123104	best: 0.8123281 (990)	total: 27.8s	remaining: 6m 28s
# 2000:	learn: 0.8564107	test: 0.8128631	best: 0.8128843 (1964)	total: 56s	remaining: 6m 3s
# 3000:	learn: 0.8723966	test: 0.8129467	best: 0.8129897 (2332)	total: 1m 23s	remaining: 5m 34s
# 4000:	learn: 0.8858802	test: 0.8130404	best: 0.8130888 (3955)	total: 1m 51s	remaining: 5m 7s
# 5000:	learn: 0.8972570	test: 0.8130633	best: 0.8131275 (4604)	total: 2m 18s	remaining: 4m 37s
# bestTest = 0.8131275177
# bestIteration = 4604
# Shrink model to first 4605 iterations.
# Accuracy score: 0.77
# Log loss: 7.86
# AUC score: 0.8131274595374376
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74     48041
#            1       0.72      0.89      0.80     47751
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7724131451478202, 'log_loss': 7.860708159284412, 'auc': 0.8131274595374376}
# Training with Fold 7
# 0:	learn: 0.7998611	test: 0.8010425	best: 0.8010425 (0)	total: 51.9ms	remaining: 12m 57s
# 1000:	learn: 0.8370957	test: 0.8150618	best: 0.8150637 (998)	total: 28.1s	remaining: 6m 32s
# 2000:	learn: 0.8561215	test: 0.8154527	best: 0.8154667 (1996)	total: 56.1s	remaining: 6m 4s
# 3000:	learn: 0.8721724	test: 0.8155903	best: 0.8156625 (2441)	total: 1m 24s	remaining: 5m 36s
# bestTest = 0.8156625032
# bestIteration = 2441
# Shrink model to first 2442 iterations.
# Accuracy score: 0.77
# Log loss: 7.79
# AUC score: 0.8156624291625425
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75     48041
#            1       0.72      0.89      0.80     47751
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7744488057457826, 'log_loss': 7.790399158450553, 'auc': 0.8156624291625425}
# Training with Fold 8
# 0:	learn: 0.8009852	test: 0.7984035	best: 0.7984035 (0)	total: 27.6ms	remaining: 6m 53s
# 1000:	learn: 0.8372569	test: 0.8103026	best: 0.8103244 (970)	total: 27.8s	remaining: 6m 28s
# 2000:	learn: 0.8561605	test: 0.8107150	best: 0.8107611 (1864)	total: 56s	remaining: 6m 3s
# 3000:	learn: 0.8720410	test: 0.8109146	best: 0.8109146 (3000)	total: 1m 23s	remaining: 5m 34s
# 4000:	learn: 0.8856109	test: 0.8112564	best: 0.8112593 (3998)	total: 1m 52s	remaining: 5m 8s
# 5000:	learn: 0.8970265	test: 0.8111967	best: 0.8113210 (4776)	total: 2m 19s	remaining: 4m 39s
# bestTest = 0.8113210201
# bestIteration = 4776
# Shrink model to first 4777 iterations.
# Accuracy score: 0.77
# Log loss: 7.90
# AUC score: 0.8113209919965716
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74     48041
#            1       0.72      0.89      0.79     47751
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7713900952062803, 'log_loss': 7.896044471484433, 'auc': 0.8113209919965716}
# Training with Fold 9
# 0:	learn: 0.8005307	test: 0.7987759	best: 0.7987759 (0)	total: 39.3ms	remaining: 9m 49s
# 1000:	learn: 0.8373320	test: 0.8107456	best: 0.8107589 (996)	total: 27.6s	remaining: 6m 26s
# 2000:	learn: 0.8561754	test: 0.8115117	best: 0.8115277 (1998)	total: 55.8s	remaining: 6m 2s
# 3000:	learn: 0.8720302	test: 0.8118589	best: 0.8118700 (2995)	total: 1m 23s	remaining: 5m 33s
# 4000:	learn: 0.8854564	test: 0.8119214	best: 0.8119293 (3984)	total: 1m 52s	remaining: 5m 8s
# 5000:	learn: 0.8968723	test: 0.8117145	best: 0.8119315 (4018)	total: 2m 20s	remaining: 4m 41s
# bestTest = 0.8119314909
# bestIteration = 4018
# Shrink model to first 4019 iterations.
# Accuracy score: 0.77
# Log loss: 7.85
# AUC score: 0.8119314233239441
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74     48041
#            1       0.72      0.89      0.80     47751
#
#     accuracy                           0.77     95792
#    macro avg       0.79      0.77      0.77     95792
# weighted avg       0.79      0.77      0.77     95792
#
# {'name': 'catboost', 'accuracy_score': 0.7727367629864706, 'log_loss': 7.849530352714907, 'auc': 0.8119314233239441}
# Training with Fold 10
# 0:	learn: 0.8002600	test: 0.7994835	best: 0.7994835 (0)	total: 27.3ms	remaining: 6m 48s
# 1000:	learn: 0.8371444	test: 0.8139710	best: 0.8139789 (999)	total: 28.3s	remaining: 6m 35s
# 2000:	learn: 0.8559567	test: 0.8146678	best: 0.8147356 (1784)	total: 56.1s	remaining: 6m 4s
# 3000:	learn: 0.8720039	test: 0.8150836	best: 0.8150999 (2967)	total: 1m 24s	remaining: 5m 36s
# 4000:	learn: 0.8853518	test: 0.8151951	best: 0.8152390 (3585)	total: 1m 51s	remaining: 5m 7s
# bestTest = 0.8152389824
# bestIteration = 3585
# Shrink model to first 3586 iterations.
# Accuracy score: 0.78
# Log loss: 7.77
# AUC score: 0.8152390315735679
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75     48040
#            1       0.72      0.89      0.80     47751
#
#     accuracy                           0.78     95791
#    macro avg       0.79      0.78      0.77     95791
# weighted avg       0.79      0.78      0.77     95791
#
# {'name': 'catboost', 'accuracy_score': 0.7751667693207086, 'log_loss': 7.765601100708763, 'auc': 0.8152390315735679}

# %% [markdown]
# ## Submisssion

# %%
probs_list = []
for cat in cats:
    probs = cat.predict_proba(test)[:, 1]
    probs_list.append(probs)
probs_array = np.array(probs_list)
mean_probs = probs_array.mean(axis=0)

# %%
mean_probs.shape
# Out:
# (493474,)

# %%
submission = pd.DataFrame({"id": list(test_ids), "claim": mean_probs})
submission.to_csv("submission.csv", index=False)
